# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("car data.csv")

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.dtypes
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# Fuel_Type         object
# Seller_Type       object
# Transmission      object
# Owner              int64
# dtype: object

# %%
df.shape
# Out:
# (301, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
print(df.Fuel_Type.value_counts())
print
# Out:
# Fuel_Type
# Petrol    239
# Diesel     60
# CNG         2
# Name: count, dtype: int64
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
print(df.Seller_Type.value_counts())
# Out:
# Seller_Type
# Dealer        195
# Individual    106
# Name: count, dtype: int64

# %%
print(df.Transmission.value_counts())
# Out:
# Transmission
# Manual       261
# Automatic     40
# Name: count, dtype: int64

# %%
df.replace({"Fuel_Type":{'Petrol':0,'Diesel':1, 'CNG':2}}, inplace= True)
# Out:
# C:\Users\mohd abdul khaleq b\AppData\Local\Temp\ipykernel_9612\2777273728.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({"Fuel_Type":{'Petrol':0,'Diesel':1, 'CNG':2}}, inplace= True)

# %%
df.replace({"Seller_Type":{'Dealer':0,'Individual':1}}, inplace= True)
# Out:
# C:\Users\mohd abdul khaleq b\AppData\Local\Temp\ipykernel_9612\4251651614.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({"Seller_Type":{'Dealer':0,'Individual':1}}, inplace= True)

# %%
df.replace({"Transmission":{'Manual':0,'Automatic':1}}, inplace= True)
# Out:
# C:\Users\mohd abdul khaleq b\AppData\Local\Temp\ipykernel_9612\276435698.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({"Transmission":{'Manual':0,'Automatic':1}}, inplace= True)

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000          0
# 1      sx4  2013           4.75           9.54       43000          1
# 2     ciaz  2017           7.25           9.85        6900          0
# 3  wagon r  2011           2.85           4.15        5200          0
# 4    swift  2014           4.60           6.87       42450          1
#
#    Seller_Type  Transmission  Owner
# 0            0             0      0
# 1            0             0      0
# 2            0             0      0
# 3            0             0      0
# 4            0             0      0

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
X=df[['Year', 'Present_Price', 'Kms_Driven',
       'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner']]

# %%
y=df['Selling_Price']

# %%
X
# Out:
#      Year  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  \
# 0    2014           5.59       27000          0            0             0
# 1    2013           9.54       43000          1            0             0
# 2    2017           9.85        6900          0            0             0
# 3    2011           4.15        5200          0            0             0
# 4    2014           6.87       42450          1            0             0
# ..    ...            ...         ...        ...          ...           ...
# 296  2016          11.60       33988          1            0             0
# 297  2015           5.90       60000          0            0             0
# 298  2009          11.00       87934          0            0             0
# 299  2017          12.50        9000          1            0             0
# 300  2016           5.90        5464          0            0             0
#
#      Owner
# 0        0
# 1        0
# 2        0
# 3        0
# ...

# %%
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1, random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test)

# %%
y_t_pred=lr.predict(X_train)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)*100
# Out:
# 83.6576671502587

# %%
r2_score(y_train,y_t_pred)*100
# Out:
# 87.99451660493716

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("AP Vs PP")
plt.show()

# %%
plt.scatter(y_train, y_t_pred)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("AP Vs PP")
plt.show()

# %%
from sklearn.linear_model import Lasso

# %%
la=Lasso()

# %%
la.fit(X_train,y_train)
# Out:
# Lasso()

# %%
y_pred=la.predict(X_test)

# %%
y_t_pred=la.predict(X_train)

# %%
r2_score(y_test,y_pred)*100
# Out:
# 87.09167941173195

# %%
r2_score(y_train,y_t_pred)*100
# Out:
# 84.27856123435794

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("AP Vs PP")
plt.show()

# %%
plt.scatter(y_train, y_t_pred)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("AP Vs PP")
plt.show()

# %%
import numpy as np

# %%
input_value=(2014,5.59,27000,0,0,0,0)

input_array=np.asarray(input_value)

input_reshape=input_array.reshape(1,-1)

pred=la.predict(input_reshape)

print(pred)
# Out:
# [3.8257306]
# C:\Users\mohd abdul khaleq b\ansel\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but Lasso was fitted with feature names
#   warnings.warn(

# %%
input_value=(2013,	9.54	,43000	,1,0	,0	,0)
input_array=np.asarray(input_value)

input_reshape=input_array.reshape(1,-1)

pred=la.predict(input_reshape)

print(pred)
# Out:
# [5.3881834]
# C:\Users\mohd abdul khaleq b\ansel\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but Lasso was fitted with feature names
#   warnings.warn(

# %%
input_value=(2013,	9.54	,43000	,1,0	,0	,0)
input_array=np.asarray(input_value)

input_reshape=input_array.reshape(1,-1)

pred=lr.predict(input_reshape)

print(pred)
# Out:
# [6.81795378]
# C:\Users\mohd abdul khaleq b\ansel\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
